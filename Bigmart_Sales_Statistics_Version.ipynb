# %% [markdown]
# <a href="https://colab.research.google.com/github/mukul-mschauhan/big-mart/blob/main/Bigmart_Sales_Statistics_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objective: We are going to solve a Machine Learning Competition from scratch.
#
# We will be working on a practical problem i.e. what generally we will see in companies.
#
# Domain(Industry/Sector): **Retail**
#
# ### Steps to the EDA
#
# 1. Problem Statement - Try to identify what all factors contribute in the problem. The objective is to ensure that the **sales** increases (in case of amazon).
#
# 2. Understand the Data -  Metadata (Data Dictionary). For example, Product Names, MRP, Location etc...
#
# 3. **Univariate Analysis** - Analyzing All the Variables but one by one. For ``numerical variables``, we can construct **histogram** or **distplot**. These plots tell us the data distribution. The general shape of Histogram is Bell Shaped Curve however, these plots can be Skewed in Nature i.e. **Positively Skewed or Negatively Skewed**.
# When it comes to ``categorical variables`` we can create **frequency plot** or **Countplot**.
#
# **Note:** Sales, Revenue, Profits, Anything involving Money will always be Positively Skewed.
#
# 4. **Bivariate Analysis**
# * Num vs Num(Target) for e.g. MRP vs Sales: **Scatterplot**
# * Cat vs Num(Target) for e.g. Product vs Sales: **Boxplot/Violin**
# * Cat vs Cat(Target) for e.g. Outlet vs Product Type: **Crosstab & Countplot**
#
# 5. Missing Values - Mean & Median Imputation for Numerical Data and Mode (Highest Freq) for Categorical Data.
#
# 6. **Outlier Analysis & Removal** - Removal: Number>Q3+1.5*IQR: Outlier | Number < Q1 - 1.5 * IQR is an Inlier.
#
# 7. **Feature Engineering** - Creating new features from the existing ones.  For example, you work for F1 Racing. Time Taken a racer to win the race. Data: Speed and Distance...
#
# 8 **Statistical Hypothesis Testing**
#
# 9. **Scaling & Transformation**: Scaling in Linear Regression, Logistic Regression, KNN & Neural Net.
#
# * Scaling - Bringing the Data on 1 Scale. Standard Scaler (Z Score Transformation) it bring the mean of each column at 0 and standard deviation at 1. Min Max Scaling where each column has a min of 0 and max of 1. (Min Max is used in Image Analysis).
#
# * If there is presence of Outlier, you want to scale the data - **Robust Scaler**
#
# * This stage of Scaling & Transformation is called **Data Preprocessing Step.**

# %% [markdown]
# ### Problem Statement:
#
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. **The aim is to build a predictive model and predict the sales of each product at a particular outlet.**
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.
#
# We have train (8523) and test (5681) data set, train data set has both input and output variable(s). You need to predict the sales for test data set.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### What is Train and Test Set??
#
# Train Set: It comprises of Input Features and target variable. This dataset is used to train the Machine Learning Model.
#
# Test Set: Once the model learns the pattern, we test the model performance by predicting the sales in the test set. So, in test set, we only have features and no target variable. Our job is to **predict the target variable using Test Set**.

# %%
train = pd.read_csv("/content/Bigmart Train.csv")
test = pd.read_csv("/content/Bigmart Test.csv")

train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
train.shape, test.shape
# Out:
# ((8523, 12), (5681, 11))

# %% [markdown]
# ### Univariate Analysis
#
# * Numerical Vars: Distplot
# * Categorical Vars: Countplot

# %% [markdown]
# Outlet Size and Item Weight has Missing Values

# %%
# Combine the Dataset
combined = pd.concat([train, test],ignore_index = True)
train.shape, test.shape, combined.shape
# Out:
# ((8523, 12), (5681, 11), (14204, 12))

# %%
# Create a List of Numerical Columns
combined.select_dtypes(include = np.number).columns

num_cols = ['Item_Weight', 'Item_Visibility', 'Item_MRP',
            'Item_Outlet_Sales']

# %%
# Plot asthetics
nrows = 2
ncols = 2 # Basis the Columns/Features that we want to plot
iterator = 1

plt.figure(figsize = (11, 6))
for i in num_cols:
  plt.subplot(nrows, ncols, iterator)
  sns.distplot(combined.loc[:, i], color = "magenta")
  plt.title(i)
  iterator = iterator+1 # it helps us in printing the plots

plt.tight_layout() # Takes care of the presentation of multiple plots..
plt.show()

# %%
# Mean = Median = Mode
combined.Item_Weight.describe() # Approximately Normal

# MRP is Multimodal...Item Outlet Sales & Visibility is Highly Skewed...
# Out:
# count    11765.000000
# mean        12.792854
# std          4.652502
# min          4.555000
# 25%          8.710000
# 50%         12.600000
# 75%         16.750000
# max         21.350000
# Name: Item_Weight, dtype: float64

# %%
# Categorical Vars...

combined.select_dtypes(include = "object").columns

cat_cols = ['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
# Total 6 Plots

nrows = 3
ncols = 3
iterator = 1

plt.figure(figsize = (11, 6))
for i in cat_cols:
  plt.subplot(nrows, ncols, iterator)
  sns.countplot(combined.loc[:, i])
  plt.title(i)
  iterator = iterator+1

plt.tight_layout()
plt.show()

# %%
# Plot the Item Type & Outlet ID
combined.Item_Type.value_counts().plot(kind = "bar")
plt.show()

# Top5 Selling Items: Fruits & Veggies, Frozen Food, Dairy, Snacks & Household..

# %%
combined.Outlet_Identifier.value_counts().plot(kind = "bar")
plt.show()

# Top3 Outlets: Out27, Out13 & Out49

# %% [markdown]
# #### Summary of Univariate Analysis
#
# * Top 5 Selling Items: Fruits & Veggies, Frozen Food, Dairy, Snacks & Household
#
# * Top 3 Outlets: Out27, Out13 & Out49
#
# * Sales & Visibility is Skewed.
#
# * Weight is Normally Distributed and MRP is Multimodal Data
#
# * Most of the Outlets in Tier 3 Cities and mostly S1.
#
# * Outlets are Medium Sized and Most Products are Low Fat Products

# %% [markdown]
# ### Bivariate Analysis

# %%
nrows = 2
ncols = 2
iterator = 1

plt.figure(figsize = (11, 7))

for i in num_cols:
  plt.subplot(nrows, ncols, iterator)
  sns.scatterplot(x = i, y = "Item_Outlet_Sales", data = combined,
                  color = "coral")
  plt.title(i)
  iterator = iterator+1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Missing Values

# %%
combined.isnull().sum()[combined.isnull().sum()!=0]
# Out:
# Item_Weight          2439
# Outlet_Size          4016
# Item_Outlet_Sales    5681
# dtype: int64

# %%
# Fix the Item Fat Content
combined.Item_Fat_Content.replace(to_replace = ['low fat', 'LF', 'reg'],
                                  value = ['Low Fat', 'Low Fat','Regular'],
                                  inplace = True)

# %%
combined.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
# Look into Pattern for Item Weight ~ which categorical col should be used
# to impute the Missing Values in Weight
combined.loc[combined.Item_Weight.isnull(), :].head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 21           FDW12          NaN          Regular         0.035400
# 23           FDC37          NaN          Low Fat         0.057557
# 29           FDC14          NaN          Regular         0.072222
# 36           FDV20          NaN          Regular         0.059512
# 38           FDX10          NaN          Regular         0.123111
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 21           Baking Goods  144.5444            OUT027
# 23           Baking Goods  107.6938            OUT019
# 29                 Canned   43.6454            OUT019
# 36  Fruits and Vegetables  128.0678            OUT027
# 38            Snack Foods   36.9874            OUT027
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 21                       1985      Medium               Tier 3
# 23                       1985       Small               Tier 1
# 29                       1985       Small               Tier 1
# 36                       1985      Medium               Tier 3
# 38                       1985      Medium               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 21  Supermarket Type3          4064.0432
# 23      Grocery Store           214.3876
# 29      Grocery Store           125.8362
# 36  Supermarket Type3          2797.6916
# 38  Supermarket Type3           388.1614

# %%
# Impute the Missing Value in the First Row
combined.loc[7, "Item_Weight"] = combined.loc[combined.Item_Identifier=="FDP10",
                                              "Item_Weight"].median()
combined.loc[18, "Item_Weight"] = combined.loc[combined.Item_Identifier=="DRI11",
                                              "Item_Weight"].median()

# %%
# Index Numbers..
rownums = combined.loc[combined.Item_Weight.isnull(), :].index
itemids = combined.loc[combined.Item_Weight.isnull(), "Item_Identifier"]

for i in rownums: # itemids[i]
   combined.loc[i, "Item_Weight"] = combined.loc[combined.Item_Identifier==itemids[i],
                                                 "Item_Weight"].median()

# %%
# Item Visibility ==== 00000
# Using Item Identifier We will remove the Item Visibility 0s...

combined['Item_Visibility'] = combined.groupby("Item_Identifier")["Item_Visibility"].\
transform(lambda x:x.replace(to_replace = 0, value = x.median()))

# %%
# Finding the Pattern Using Item Type
val  = combined.loc[combined.Item_Type=="Fruits and Vegetables",
                    "Item_Visibility"].median()

# %%
# Imputting the Value
combined.loc[combined.Item_Visibility==0,'Item_Visibility'] = val

# %%
# Plotting the Item Visibility
plt.figure(figsize = (12, 7))
sns.scatterplot(x = "Item_Visibility", y = "Item_Outlet_Sales", data = combined,
                color = "magenta")
plt.show()

# %%
# Missing Values in the Data
combined.isnull().sum()[combined.isnull().sum()!=0]
# Out:
# Outlet_Size          4016
# Item_Outlet_Sales    5681
# dtype: int64

# %%
combined.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.022914
# 4           NCD19         8.93          Low Fat         0.013177
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
combined.Outlet_Size.value_counts() # Mode: Medium
# Out:
# Outlet_Size
# Medium    4655
# Small     3980
# High      1553
# Name: count, dtype: int64

# %%
combined.loc[combined.Outlet_Size=="Medium", "Outlet_Identifier"].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT027'], dtype=object)

# %%
plt.figure(figsize = (12, 7))
sns.boxplot(x = "Outlet_Identifier",
            y = "Item_Outlet_Sales", data = combined)
plt.show()

# %% [markdown]
# OUT027 is a High Profit Making Outlet

# %%
#combined.loc[combined.Outlet_Size.isnull(),
  #           "Outlet_Identifier"].unique()

combined.loc[combined.Outlet_Size.isnull(),
             "Outlet_Type"].unique()
# Out:
# array(['Grocery Store', 'Supermarket Type1'], dtype=object)

# %%
# Generate a Truth Table
combined.groupby(["Outlet_Identifier",
                  "Outlet_Location_Type", "Outlet_Type"])["Outlet_Size"].describe()
# Out:
#                                                          count unique     top  \
# Outlet_Identifier Outlet_Location_Type Outlet_Type
# OUT010            Tier 3               Grocery Store         0      0     NaN
# OUT013            Tier 3               Supermarket Type1  1553      1    High
# OUT017            Tier 2               Supermarket Type1     0      0     NaN
# OUT018            Tier 3               Supermarket Type2  1546      1  Medium
# OUT019            Tier 1               Grocery Store       880      1   Small
# OUT027            Tier 3               Supermarket Type3  1559      1  Medium
# OUT035            Tier 2               Supermarket Type1  1550      1   Small
# OUT045            Tier 2               Supermarket Type1     0      0     NaN
# OUT046            Tier 1               Supermarket Type1  1550      1   Small
# OUT049            Tier 1               Supermarket Type1  1550      1  Medium
#
#                                                           freq
# Outlet_Identifier Outlet_Location_Type Outlet_Type
# OUT010            Tier 3               Grocery Store       NaN
# OUT013            Tier 3               Supermarket Type1  1553
# OUT017            Tier 2               Supermarket Type1   NaN
# OUT018            Tier 3               Supermarket Type2  1546
# OUT019            Tier 1               Grocery Store       880
# OUT027            Tier 3               Supermarket Type3  1559
# OUT035            Tier 2               Supermarket Type1  1550
# OUT045            Tier 2               Supermarket Type1   NaN
# OUT046            Tier 1               Supermarket Type1  1550
# OUT049            Tier 1               Supermarket Type1  1550

# %%
# Imputted Outlet Size where Type is Grocery
combined.loc[combined.Outlet_Type=="Grocery Store",
             "Outlet_Size"] = "Small"

# %%
combined.loc[combined.Outlet_Size.isnull(), "Outlet_Location_Type"].unique()
# 45 and 17 Outlets
# Tier 2

# Imputted Outlet Size where Type is S1 in Tier 2 City
combined.loc[(combined.Outlet_Type=="Supermarket Type1") & \
 (combined.Outlet_Size.isnull()), "Outlet_Size"]="Small"

# %%
combined.Outlet_Size.unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
combined.isnull().sum()[combined.isnull().sum()!=0]
# Out:
# Item_Outlet_Sales    5681
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
combined.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.022914
# 4           NCD19         8.93          Low Fat         0.013177
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999       Small               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999       Small               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987       Small               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Item_ID
# 0  Supermarket Type1          3735.1380      FD
# 1  Supermarket Type2           443.4228      DR
# 2  Supermarket Type1          2097.2700      FD
# 3      Grocery Store           732.3800      FD
# 4  Supermarket Type1           994.7052      NC

# %%
# Extracting food code from the Item IDs.
ids = []
for i in combined.Item_Identifier:
  ids.append(i[:2])

# %%
combined["Item_ID"]=pd.Series(ids)

# %%
sns.boxplot(x = "Item_ID",
            y = "Item_Outlet_Sales", data = combined)
plt.show()

# %%
combined.groupby("Item_ID")["Item_Fat_Content"].describe()
# Out:
#          count unique         top  freq
# Item_ID
# DR        1317      1    Low_KCal  1317
# FD       10201      2     Low Fat  5291
# NC        2686      1  Non_Edible  2686

# %%
# Where the Item ID is NC, Item Fat Content = Non_Edible

combined.loc[combined.Item_ID=='NC', "Item_Fat_Content"] = "Non_Edible"
combined.loc[combined.Item_ID=='DR', "Item_Fat_Content"] = "Low_KCal"

# %%
combined.groupby("Item_Fat_Content")["Item_Outlet_Sales"].describe()
# Out:
#                    count         mean          std      min       25%  \
# Item_Fat_Content
# Low Fat           3190.0  2198.637111  1746.275688  36.6190  846.8976
# Low_KCal           799.0  1997.333337  1650.197412  33.2900  760.6765
# Non_Edible        1599.0  2142.721364  1626.907672  33.2900  815.6050
# Regular           2935.0  2233.523758  1717.167995  33.9558  866.2058
#
#                         50%        75%         max
# Item_Fat_Content
# Low Fat           1774.6899  3103.2938  11445.1020
# Low_KCal          1496.7184  2864.9374   9554.2300
# Non_Edible        1874.8928  3016.7398  13086.9648
# Regular           1846.9292  3211.1534  12117.5600

# %%
combined.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %% [markdown]
# * In categorical data, if there are lots of labels/categories in that column, while treating the categorical data, it will generate as many columns as categories...
#
# * So What, I will use Label Encoding....
#
# * You cannot use Label Encoding because LE is used in Ordinal Variables for e.g. Shirt Size S, M and L. S vs M vs L. Thus, the Label Encoding is only Used when the Data is Ordinal in Nature.
#
# Thus, I know that I will be able to use One Hot Encoding. Thus my data will suffer from **Curse of Dimensions**. The Curse of Dimensions mean that if there are lots of columns in the data, it means it has a very high Dimension and thus, building ML Models is quite difficult.

# %%
# Bin the Categories

perishables  = ['Dairy', 'Meat', 'Fruits and Vegetables',
       'Breakfast', 'Breads', 'Starchy Foods','Seafood']

def perish(x):
  if x in perishables:
    return "Perishables"
  else:
    return "Non_Perishables"

# %%
combined["Item_Type_Cat"] = combined.Item_Type.apply(perish)

# %%
# Statistical Summary of all the Item Types...
combined.groupby("Item_Type")["Item_Outlet_Sales"].describe()
# Out:
#                         count         mean          std       min        25%  \
# Item_Type
# Baking Goods            648.0  1952.971207  1546.788045   37.2848  705.08220
# Breads                  251.0  2204.132226  1644.235914   35.2874  968.73900
# Breakfast               110.0  2111.808651  1911.693586   39.9480  679.11600
# Canned                  649.0  2225.194904  1645.235638   37.9506  952.09400
# Dairy                   682.0  2232.542597  1884.404698   40.6138  788.97300
# Frozen Foods            856.0  2132.867744  1724.777720   36.6190  808.94700
# Fruits and Vegetables  1232.0  2289.009592  1799.503459   45.2744  884.84820
# Hard Drinks             214.0  2139.221622  1606.191587   37.9506  834.91320
# Health and Hygiene      520.0  2010.000265  1553.633063   34.6216  758.84555
# Household               910.0  2258.784300  1692.245757   33.2900  853.38915
# Meat                    425.0  2158.977911  1695.231081   47.9376  782.98080
# Others                  169.0  1926.139702  1431.860471   39.9480  790.97040
# Seafood                  64.0  2326.065928  1842.988719  149.8050  473.38380
# Snack Foods            1200.0  2277.321739  1705.121755   33.9558  918.80400
# Soft Drinks             445.0  2006.511735  1674.249752   33.2900  771.66220
# Starchy Foods           148.0  2374.332773  1773.945328   58.5904  958.75200
#
#                              50%         75%         max
# Item_Type
# Baking Goods           1577.9460  2823.82425   7931.6754
# Breads                 1860.2452  3145.90500   8958.3390
# Breakfast              1554.6430  2970.30025   8209.3140
# Canned                 1860.2452  3101.29640  10306.5840
# Dairy                  1650.8511  3296.20935  10256.6490
# Frozen Foods           1687.1372  3079.49145   9678.0688
# Fruits and Vegetables  1830.9500  3227.13260  12117.5600
# Hard Drinks            1816.6353  3071.33540   7843.1240
# Health and Hygiene     1669.4935  2884.57850   9779.9362
# Household              1981.4208  3236.78670  13086.9648
# Meat                   1829.6184  3036.04800   9390.4432
# Others                 1713.7692  2719.79300   6008.8450
# Seafood                2055.3246  3589.32780   6503.5344
# Snack Foods            1944.1360  3143.57470  10993.6896
# Soft Drinks            1518.0240  2759.07520   9554.2300
# Starchy Foods          1968.1048  3592.65680   8132.0812

# %%
# Target Encoding ~ Item Type

combined["Magic1"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("count")
combined["Magic2"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("min")
combined["Magic3"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("max")
combined["Magic4"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("mean")
combined["Magic5"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("median")
combined["Magic6"]=combined.groupby("Item_Type")["Item_Outlet_Sales"].transform("std")

# %%
# Outlet_Identifier
combined["Magic7"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("count")
combined["Magic8"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("min")
combined["Magic9"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("max")
combined["Magic10"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("mean")
combined["Magic11"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("median")
combined["Magic12"]=combined.groupby("Outlet_Identifier")["Item_Outlet_Sales"].transform("std")

# %%
pd.set_option('display.max_columns', 100)
combined.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92         Low_KCal         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999       Small
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Item_ID  \
# 0               Tier 1  Supermarket Type1          3735.1380      FD
# 1               Tier 3  Supermarket Type2           443.4228      DR
#
#      Item_Type_Cat  Magic1   Magic2     Magic3       Magic4     Magic5  \
# 0      Perishables     682  40.6138  10256.649  2232.542597  1650.8511
# 1  Non_Perishables     445  33.2900   9554.230  2006.511735  1518.0240
#
#         Magic6  Magic7    Magic8     Magic9      Magic10    Magic11  \
# 0  1884.404698     930  111.8544  7646.0472  2348.354635  1966.1074
# 1  1674.249752     928   69.2432  6768.5228  1995.498739  1655.1788
#
#        Magic12
# 0  1513.289464
# 1  1375.932889

# %%
combined.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
best = ["OUT027", "OUT013", "OUT046"]
worst = ["OUT010", "OUT019"]

def outlets(x):
  if x in best:
    return("Best")
  elif x in worst:
    return("Worst")
  else:
    return("Average")

# %%
combined["Outlets_ID"] = combined.Outlet_Identifier.apply(outlets)

# %%
sns.boxplot(x = "Outlets_ID", y = "Item_Outlet_Sales", data = combined)
plt.show()

# %%
combined.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Item_ID', 'Item_Type_Cat',
#        'Magic1', 'Magic2', 'Magic3', 'Magic4', 'Magic5', 'Magic6', 'Magic7',
#        'Magic8', 'Magic9', 'Magic10', 'Magic11', 'Magic12', 'Outlets_ID'],
#       dtype='object')

# %%
new = combined.drop(['Item_Identifier', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Establishment_Year'], axis = 1)

# %%
new.Outlet_Size.unique()
# Out:
# array(['Small', 'Medium'], dtype=object)

# %%
# Split the Data into Original Train and test

newtrain = new.loc[0:train.shape[0]-1, :]
newtest = new.loc[train.shape[0]:, :]

# Remove the Target Var from the Test Set
newtest.drop("Item_Outlet_Sales", axis = 1,
             inplace = True)

train.shape, test.shape, newtrain.shape, newtest.shape # train has n and test has n-1 cols
# Out:
# ((8523, 12), (5681, 11), (8523, 23), (5681, 22))

# %% [markdown]
# 1. Univariate Analysis
# 2. Bivariate Analysis
# 3. Missing Values
# 4. Feature Engineering
#
# ### Encoding & Feature Scaling
#
# Is it Important to Split the Data back into train and test before Scaling?
#
# Yes, this is to ensure that there is no data leakage. We cannot expose our test set with the training set when it comes to model building or scaling the data.
#
# How to ensure this?
#
# * We apply ``fit_transform`` in train when we scale the training data and we apply ``.transform`` when scaling the test set.
#
# When fi_transform works, it will calculate the mean and standard deviation of each column and will do the transformation. So, Standard Scaler model has learnt from the Training Set and what it has learnt - **mean and sd**.
#
# Now, the model will use the mean and standard deviation of the training set to transform the test set. This is the correct approach while scaling the data.

# %%
# Divide the Data in X and y

# X represents input for model and y is the target/output for the model

X = newtrain.drop("Item_Outlet_Sales", axis = 1)
y = newtrain.Item_Outlet_Sales

X.columns, newtest.columns
# Out:
# (Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP',
#         'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_ID',
#         'Item_Type_Cat', 'Magic1', 'Magic2', 'Magic3', 'Magic4', 'Magic5',
#         'Magic6', 'Magic7', 'Magic8', 'Magic9', 'Magic10', 'Magic11', 'Magic12',
#         'Outlets_ID'],
#        dtype='object'),
#  Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP',
#         'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_ID',
#         'Item_Type_Cat', 'Magic1', 'Magic2', 'Magic3', 'Magic4', 'Magic5',
#         'Magic6', 'Magic7', 'Magic8', 'Magic9', 'Magic10', 'Magic11', 'Magic12',
#         'Outlets_ID'],
#        dtype='object'))

# %%
# Extract the Numerical Columns
num_cols = X.select_dtypes(include = np.number).columns

# %%
# Scaling the train Set

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

for i in num_cols:
  X.loc[:, i] = scaler.fit_transform(pd.DataFrame(X.loc[:, i])) # Scaler learns mean and sd
  newtest.loc[:, i] = scaler.transform(pd.DataFrame(newtest.loc[:, i])) # .transform will use the mean and sd to transform test set

# %% [markdown]
# ### About Standard Scaler
#
# * Standard Scaler is known as Z Score Transformation. It takes the data substract it from mean and divide it by Standard Deviation.
#
# * The values obtained are called Z Score Values. We scale the data in such a way such that the Mean is 0 and Standard Deviation is 1.
#
# ### Example of Standard Scaler

# %%
# Example of Scaling

df = pd.DataFrame({"Col1": [1, 2, 3, 4, 10],
                   "Col2":[100, 250, 129, 234, 109]})

# %%
# Manual Approach: (x-mew)/sd

mew_col1 = df.Col1.mean()
sd_col1 = df.Col1.std(ddof = 0) # Divide it by N as Python by default divides by n-1
df["trf_col1"] = (df.Col1 - mew_col1)/sd_col1

# %%
# Col2:
mean_col2 = df.Col2.mean()
sd_col2 = df.Col2.std(ddof = 0) # Divide it by N as Python by default divides by n-1

df["trf"] = (df.Col2 - mean_col2)/sd_col2

# %%
df.describe()
# Out:
#             Col1        Col2      trf_col1           trf
# count   5.000000    5.000000  5.000000e+00  5.000000e+00
# mean    4.000000  164.400000  4.440892e-17 -1.110223e-16
# std     3.535534   71.835228  1.000000e+00  1.000000e+00
# min     1.000000  100.000000 -8.485281e-01 -8.964961e-01
# 25%     2.000000  109.000000 -5.656854e-01 -7.712094e-01
# 50%     3.000000  129.000000 -2.828427e-01 -4.927944e-01
# 75%     4.000000  234.000000  0.000000e+00  9.688840e-01
# max    10.000000  250.000000  1.697056e+00  1.191616e+00

# %%
sc = StandardScaler()

df["Scaled1"] = sc.fit_transform(pd.DataFrame(df.loc[:, 'Col1']))
df["Scaled2"] = sc.fit_transform(pd.DataFrame(df.loc[:, 'Col2']))

# %%
df.head()
# Out:
#    Col1  Col2  trf_col1       trf   Scaled1   Scaled2
# 0     1   100 -0.948683 -1.002313 -0.948683 -1.002313
# 1     2   250 -0.632456  1.332267 -0.632456  1.332267
# 2     3   129 -0.316228 -0.550961 -0.316228 -0.550961
# 3     4   234  0.000000  1.083245  0.000000  1.083245
# 4    10   109  1.897367 -0.862238  1.897367 -0.862238

# %%
# Min Max Scaler:: It is used in Image Processing

from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()

df["minmax1"] = minmax.fit_transform(pd.DataFrame(df.Col1))
df["minmax2"] = minmax.fit_transform(pd.DataFrame(df.Col2))

# Min Max Scales the Data in such a way that each col has min value 0 and Max as 1.
# It is never used when there is a presence of Outliers.
# Tip: Use Robust Scaler when there is a presence of Outlier in the Data

# %%
df.head()
# Out:
#    Col1  Col2  trf_col1       trf   Scaled1   Scaled2   minmax1   minmax2
# 0     1   100 -0.948683 -1.002313 -0.948683 -1.002313  0.000000  0.000000
# 1     2   250 -0.632456  1.332267 -0.632456  1.332267  0.111111  1.000000
# 2     3   129 -0.316228 -0.550961 -0.316228 -0.550961  0.222222  0.193333
# 3     4   234  0.000000  1.083245  0.000000  1.083245  0.333333  0.893333
# 4    10   109  1.897367 -0.862238  1.897367 -0.862238  1.000000  0.060000

# %% [markdown]
# ### Transformation
#
# * Why Transform?
#
# Most of the Machine Learning Models have an assumption that the Data should be Normally Distributed. For example, **Linear Regression** and **Logistic Regression** followed by KNNs are some of the model which expect the data to be Scaled and Normalized.
#
# * This is the reason Transformation is applied on the data.
#
# **Different Types of Transformations**
#
# * Log Transformation/Exponential Transformation
# * Log Normal Transformation (Finance)
# * Square Root Transformation
# * **Box Cox Transformation**
# * **Yeo-Johnson Transformation**
#
# The objective of the transformation is to make sure that the model is able to capture the pattern very well.

# %%
# Reduce the Skewness in the Data
sns.distplot(newtrain.Item_Visibility)

newtrain.Item_Visibility.skew() # Data is normal when the Skewness is 0
# Out:
# 1.2130786409757208

# %%
# Log Transformation
np.log(newtrain.Item_Visibility).skew() # Original Data- 1.21 | Log:-0.43319
# Out:
# -0.43319823861840084

# %%
sns.distplot(np.log(newtrain.Item_Visibility))
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %%
# Exp Transformation
np.exp(newtrain.Item_Visibility).skew() # Original Data- 1.21 | Exp: 1.33
# Out:
# 1.3997827808681564

# %%
# Sqrt Transformation
np.sqrt(newtrain.Item_Visibility).skew() # Original Data- 1.21 | SQRT: 0.39
# Out:
# 0.39717214000550216

# %%
sns.distplot(np.sqrt(newtrain.Item_Visibility))
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %%
# Box Cox Transformation

from scipy.stats import boxcox

# boxcox, lambda
boxvals, lambda_val = boxcox(newtrain.Item_Visibility)

import scipy.stats as stats
stats.skew(boxvals) # Original Data- 1.21 | Box: -0.03

# Box Cox transformation works on Positive Data Only and not on -ve Data.
# Background of Box Cox involves usage of Log Function...
# Out:
# -0.0363170628399697

# %%
#sns.distplot(boxvals)
pd.DataFrame(boxvals).describe()
# Out:
#                  0
# count  8523.000000
# mean     -2.093712
# std       0.393353
# min      -3.154667
# 25%      -2.385786
# 50%      -2.089440
# 75%      -1.799370
# max      -0.982142

# %%
# Yeo Johnson

# it can handle negative values...

from sklearn.preprocessing import PowerTransformer
power = PowerTransformer(method = "yeo-johnson")
vals = power.fit_transform(pd.DataFrame(newtrain.Item_Visibility))

# %%
stats.skew(vals) # Original Data- 1.21 | YJ: 0.15
# Out:
# array([0.15407182])

# %% [markdown]
# ### How to Decide if we need to do any Scaling or Transformation
#
# * Models like Linear Regression, Logistic Regression, KNN need Transformation
# * Models like Linear Regression, Logistic Regression, KNN & Neural Net expect us to Scale the Data before Building Model
#
# * Objective of Transformation is to reduce the skewness so if the data is not skewed or very light skewed, you dont need transformation and you can build the model directly.
#
# * Models like Decision Tree, Random Forest, Gradient Boosting, Xtreme Gradient Boosting Machines dont expect you to either scale or Transform Data. You can directly take the data and build the model and do the predictions.

# %% [markdown]
# ## Train and Test Set

# %%
# Example of Splitting the Data in Train and test...
tips = sns.load_dataset("tips")
from sklearn.model_selection import train_test_split

X = tips.drop("tip", axis = 1)
y = tips.tip

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20,
                                                random_state = 41)

# %%
#Xtrain and Y Train = Train data
# Xtest = Test Set
# Ytest = Stored in the backend...

# %% [markdown]
# ### Statistical Test
#
# * Hypothesis Tests are applied on the training data

# %%
newtrain.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP Outlet_Size  \
# 0         9.30          Low Fat         0.016047  249.8092       Small
# 1         5.92         Low_KCal         0.019278   48.2692      Medium
# 2        17.50          Low Fat         0.016760  141.6180       Small
# 3        19.20          Regular         0.022914  182.0950       Small
# 4         8.93       Non_Edible         0.013177   53.8614       Small
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Item_ID  \
# 0               Tier 1  Supermarket Type1          3735.1380      FD
# 1               Tier 3  Supermarket Type2           443.4228      DR
# 2               Tier 1  Supermarket Type1          2097.2700      FD
# 3               Tier 3      Grocery Store           732.3800      FD
# 4               Tier 3  Supermarket Type1           994.7052      NC
#
#      Item_Type_Cat  Magic1   Magic2      Magic3       Magic4     Magic5  \
# 0      Perishables     682  40.6138  10256.6490  2232.542597  1650.8511
# 1  Non_Perishables     445  33.2900   9554.2300  2006.511735  1518.0240
# 2      Perishables     425  47.9376   9390.4432  2158.977911  1829.6184
# 3      Perishables    1232  45.2744  12117.5600  2289.009592  1830.9500
# 4  Non_Perishables     910  33.2900  13086.9648  2258.784300  1981.4208
#
#         Magic6  Magic7    Magic8      Magic9      Magic10    Magic11  \
# 0  1884.404698     930  111.8544   7646.0472  2348.354635  1966.1074
# 1  1674.249752     928   69.2432   6768.5228  1995.498739  1655.1788
# 2  1695.231081     930  111.8544   7646.0472  2348.354635  1966.1074
# 3  1799.503459     555   33.2900   1775.6886   339.351662   250.3408
# 4  1692.245757     932   73.2380  10256.6490  2298.995256  2050.6640
#
#        Magic12 Outlets_ID
# 0  1513.289464    Average
# 1  1375.932889    Average
# 2  1513.289464    Average
# 3   271.014855      Worst
# 4  1533.531664       Best

# %%
newtrain.select_dtypes(include = np.number).columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales',
#        'Magic1', 'Magic2', 'Magic3', 'Magic4', 'Magic5', 'Magic6', 'Magic7',
#        'Magic8', 'Magic9', 'Magic10', 'Magic11', 'Magic12'],
#       dtype='object')

# %%
nums = ['Item_Weight', 'Item_Visibility', 'Item_MRP',
       'Magic1', 'Magic2', 'Magic3', 'Magic4', 'Magic5', 'Magic6', 'Magic7',
       'Magic8', 'Magic9', 'Magic10', 'Magic11', 'Magic12']

# Num vs Num => T Test
# Ho: Predictors and Target Var are not Related/Independent.
# In Simple words, Item MRP has no relation with the Sales
# Ha: Predictors and target are related.

predictor = newtrain.loc[:, "Item_MRP"]

import scipy.stats as stats
stats.ttest_ind(predictor, newtrain.Item_Outlet_Sales)
# Out:
# TtestResult(statistic=-110.30476318014294, pvalue=0.0, df=17044.0)

# %%
pvals = []

for i in nums:
  teststats, pvalue = stats.ttest_ind(newtrain.loc[:, i],
                                      newtrain.Item_Outlet_Sales)
  pvals.append(pvalue)

# %%
pd.DataFrame(pvals, index = nums, columns = ["P-Values"]).\
sort_values(by = "P-Values", ascending = False) # 4 and 10
# Out:
#                       P-Values
# Magic4            1.000000e+00
# Magic10           1.000000e+00
# Magic11           3.178472e-49
# Magic5            9.443741e-98
# Magic6           1.556293e-145
# Item_Weight       0.000000e+00
# Item_Visibility   0.000000e+00
# Item_MRP          0.000000e+00
# Magic1            0.000000e+00
# Magic2            0.000000e+00
# Magic3            0.000000e+00
# Magic7            0.000000e+00
# Magic8            0.000000e+00
# Magic9            0.000000e+00
# Magic12           0.000000e+00

# %% [markdown]
# ### Anova

# %%
# List of the Categorical Vars
newtrain.select_dtypes(include = "object").columns
# Out:
# Index(['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_ID', 'Item_Type_Cat', 'Outlets_ID'],
#       dtype='object')

# %%
# Ho: Item Fat Content has no relation with the Target
# Ha: Ho is False. They are Related

import statsmodels.formula.api as sfa
from statsmodels.stats.anova import anova_lm

model = sfa.ols("Item_Outlet_Sales~Item_Fat_Content+Outlet_Size+\
Outlet_Location_Type+Outlet_Type+Item_ID+Item_Type_Cat+Outlets_ID",
                data = newtrain).fit()

print(anova_lm(model))
# Out:
#                           df        sum_sq       mean_sq           F  \
# Item_Fat_Content         3.0  3.838447e+07  1.279482e+07    5.786441
# Outlet_Size              1.0  1.055219e+09  1.055219e+09  477.221089
# Outlet_Location_Type     2.0  6.064914e+08  3.032457e+08  137.142451
# Outlet_Type              3.0  4.281541e+09  1.427180e+09  645.440278
# Item_ID                  2.0  2.475585e+05  1.237792e+05    0.055979
# Item_Type_Cat            1.0  1.456944e+07  1.456944e+07    6.589009
# Outlets_ID               2.0  2.590899e+06  1.295449e+06    0.585865
# Residual              8512.0  1.882151e+10  2.211173e+06         NaN
#
#                              PR(>F)
# Item_Fat_Content       6.008311e-04
# Outlet_Size           5.584252e-103
# Outlet_Location_Type   2.394833e-59
# Outlet_Type            0.000000e+00
# Item_ID                9.455594e-01
# Item_Type_Cat          1.027797e-02
# Outlets_ID             5.566466e-01
# Residual                        NaN

# %%
newtrain.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP Outlet_Size  \
# 0         9.30          Low Fat         0.016047  249.8092       Small
# 1         5.92         Low_KCal         0.019278   48.2692      Medium
# 2        17.50          Low Fat         0.016760  141.6180       Small
# 3        19.20          Regular         0.022914  182.0950       Small
# 4         8.93       Non_Edible         0.013177   53.8614       Small
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Item_ID  \
# 0               Tier 1  Supermarket Type1          3735.1380      FD
# 1               Tier 3  Supermarket Type2           443.4228      DR
# 2               Tier 1  Supermarket Type1          2097.2700      FD
# 3               Tier 3      Grocery Store           732.3800      FD
# 4               Tier 3  Supermarket Type1           994.7052      NC
#
#      Item_Type_Cat  Magic1   Magic2      Magic3       Magic4     Magic5  \
# 0      Perishables     682  40.6138  10256.6490  2232.542597  1650.8511
# 1  Non_Perishables     445  33.2900   9554.2300  2006.511735  1518.0240
# 2      Perishables     425  47.9376   9390.4432  2158.977911  1829.6184
# 3      Perishables    1232  45.2744  12117.5600  2289.009592  1830.9500
# 4  Non_Perishables     910  33.2900  13086.9648  2258.784300  1981.4208
#
#         Magic6  Magic7    Magic8      Magic9      Magic10    Magic11  \
# 0  1884.404698     930  111.8544   7646.0472  2348.354635  1966.1074
# 1  1674.249752     928   69.2432   6768.5228  1995.498739  1655.1788
# 2  1695.231081     930  111.8544   7646.0472  2348.354635  1966.1074
# 3  1799.503459     555   33.2900   1775.6886   339.351662   250.3408
# 4  1692.245757     932   73.2380  10256.6490  2298.995256  2050.6640
#
#        Magic12 Outlets_ID
# 0  1513.289464    Average
# 1  1375.932889    Average
# 2  1513.289464    Average
# 3   271.014855      Worst
# 4  1533.531664       Best

# %%
# Item Fat Content vs Item ID

# Ho: Item ID and Fat Content are not Related/Independent
# Ha: Ho is False

tbl = pd.crosstab(newtrain.Item_Fat_Content, newtrain.Item_ID)

# Chi Square Test
teststats, pvalue, df, expected_values = stats.chi2_contingency(tbl)
print(pvalue)
# Out:
# 0.0

# %%
# Outlet_Type vs Item ID

# Ho: Item ID and Outlet_Type are not Related/Independent
# Ha: Ho is False
tbl = pd.crosstab(newtrain.Outlet_Type, newtrain.Item_ID)

# Chi Square Test
teststats, pvalue, df, expected_values = stats.chi2_contingency(tbl)
print(pvalue)
# Out:
# 0.8999461250550979

# %%
# Remove the Magic4 and 10

newtrain.drop(["Magic4", "Magic10"], axis  =1, inplace = True)
newtest.drop(["Magic4", "Magic10"], axis  =1, inplace = True)

# %%
# Splitting the Train Data in X and y
X = newtrain.drop("Item_Outlet_Sales", axis = 1)
y = newtrain.Item_Outlet_Sales

# %%
# Outlet_Size = Order|Sequence
X.Outlet_Size.unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
mapped = {"Medium":3, "High":2, "Small":1}

X['Outlet_Size'] = X.Outlet_Size.map(mapped)
newtest['Outlet_Size'] = newtest.Outlet_Size.map(mapped)

# %%
# dummies
dummyx = pd.get_dummies(X, drop_first = True)
dummytest = pd.get_dummies(newtest, drop_first = True)

# %% [markdown]
# ### Modeling

# %%
from sklearn.linear_model import LinearRegression

# Machine Instance
lr = LinearRegression()

# Fit and Predict
pred = lr.fit(dummyx, y).predict(dummytest)

# %%
# Submission File

submission = pd.DataFrame({"Item_Identifier":test.Item_Identifier,
              "Outlet_Identifier":test.Outlet_Identifier,
              "Item_Outlet_Sales":np.abs(pred)})

# %%
# Export Outside
submission.to_csv("LRMODEL.csv", index = False) # 1151

# %%
# Gradient Boosting Machines
from sklearn.ensemble import GradientBoostingRegressor

# Machine Instance
gbm = GradientBoostingRegressor()
pred = gbm.fit(dummyx, y).predict(dummytest)

# %%
# Submission File

submission = pd.DataFrame({"Item_Identifier":test.Item_Identifier,
              "Outlet_Identifier":test.Outlet_Identifier,
              "Item_Outlet_Sales":np.abs(pred)})

# Export Outside
submission.to_csv("GBMMODEL.csv", index = False) # 1151

# %% [markdown]
# ### Regularization

# %%
# Analysis of Weights
weights = pd.DataFrame(lr.coef_,
                       columns = ["Weights"], index = dummyx.columns)

# %%
# Visualizing the Weights
weights.sort_values(by = "Weights",
                    ascending = False).plot(kind = "bar")
# Out:
# <Axes: >

# %%
# Analysis of Weights
weights = pd.DataFrame(gbm.feature_importances_,
                       columns = ["Weights"], index = dummyx.columns)

# Visualizing the Weights

weights.sort_values(by = "Weights",
                    ascending = False).plot(kind = "bar")
# Out:
# <Axes: >

# %%
# Ridge Regression
from sklearn.linear_model import Lasso, Ridge
# Machine Instance
ridge = Ridge(alpha = 0.1)
pred = ridge.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(ridge.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >

# %%
ridge = Ridge(alpha = 10)
pred = ridge.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(ridge.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >

# %%
ridge = Ridge(alpha = 50)
pred = ridge.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(ridge.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >

# %%
ridge = Ridge(alpha = 100)
pred = ridge.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(ridge.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ### Lasso Regression

# %%
lasso = Lasso(alpha = 1)
pred = lasso.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(lasso.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import ElasticNet
enet = ElasticNet(alpha = 10, l1_ratio = 1)

pred = enet.fit(dummyx, y).predict(dummytest)

# %%
pd.DataFrame(enet.coef_, columns = ["Weights"], index = dummyx.columns).\
sort_values(ascending = False, by = "Weights").plot(kind = "bar")
# Out:
# <Axes: >
